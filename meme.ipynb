# %%
import pandas as pd

# %%
df = pd.read_csv("tamkrasae.csv")

# %%
df.columns
# Out:
# Index(['alt', 'comments', 'facebookUrl', 'images/0/thumb', 'isVideo', 'likes',
#        'link', 'pageId', 'postId', 'shares', 'text', 'thumb', 'time',
#        'timestamp', 'topLevelUrl', 'url'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2425 entries, 0 to 2424
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   alt             96 non-null     object
#  1   comments        2424 non-null   float64
#  2   facebookUrl     2425 non-null   object
#  3   images/0/thumb  6 non-null      object
#  4   isVideo         345 non-null    object
#  5   likes           2425 non-null   int64
#  6   link            1955 non-null   object
#  7   pageId          2420 non-null   float64
#  8   postId          2420 non-null   float64
#  9   shares          2421 non-null   float64
#  10  text            2421 non-null   object
#  11  thumb           2366 non-null   object
#  12  time            2425 non-null   object
#  13  timestamp       2425 non-null   int64
#  14  topLevelUrl     2420 non-null   object
#  15  url             2425 non-null   object
# dtypes: float64(4), int64(2), object(10)
# ...

# %%
df = df.drop(["alt","facebookUrl","images/0/thumb","link","pageId","postId","time"],axis=1)

# %%
df = df[df.isVideo != True]

# %%
from datetime import datetime
df["timestamp"] = [datetime.fromtimestamp(x/1000).date() for x in df["timestamp"]]

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], format='%Y-%m-%d')
df = df.loc[(df["timestamp"] >= "2020-01-01")]

# %%
df
# Out:
#       comments isVideo  likes  shares  \
# 1         17.0     NaN    577   200.0
# 3         22.0     NaN    964   264.0
# 4        209.0     NaN   5200  2700.0
# 6        149.0     NaN   2500  1200.0
# 8         18.0     NaN    334   105.0
# ...        ...     ...    ...     ...
# 2308      29.0     NaN   1600    71.0
# 2309     382.0     NaN   3400   337.0
# 2310      43.0     NaN   3700   267.0
# 2311     406.0     NaN   3000   580.0
# 2312     101.0     NaN   7300   467.0
#
#                                                    text  \
# 1                                 ห้ะ อ๋อ เอ๊อะ เอ๊ะ 🤔?
# 3                                                  MOOD
# 4                              กลายเป็นดาราสาวท่านหนึ่ง
# 6     ประหยัดแบบ ตัวแม่ ตัวมัม ตัวมารดา ตัวบรรพบุรุษ...
# 8                                                  MOOD
# ...                                                 ...
# 2308  เกิดอะไรขึ้นหรอคะช่วงนี้ จีจี้เห็นหลายคนทำท่าโ...
# ...
